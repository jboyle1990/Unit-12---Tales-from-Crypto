# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\12152\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable

load_dotenv("classkeys.env")
api_key = os.getenv("news_api")

# %%
print(api_key)
# Out:
# 6fb642cc03e54c0ba1db100a02479da5

# %%
# Create a newsapi client

from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles

bitcoin_articles = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles

ethereum_articles = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "Text": text,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu
            
        })
        
    except AttributeError:
        pass

# Create DataFrame
btc_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["Compound",  "Negative", "Neutral","Positive","Text"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.7351     0.000    0.853     0.147
# 1    0.0000     0.000    1.000     0.000
# 2   -0.7713     0.169    0.831     0.000
# 3   -0.1779     0.067    0.887     0.046
# 4    0.0000     0.000    1.000     0.000
#
#                                                 Text
# 0  Even in cyberspace, the Department of Justice ...
# 1  When Russia invaded Ukraine, Niki Proshin was ...
# 2  "Bitcoin was seen by many of its libertarian-l...
# 3  Feb 22 (Reuters) - Bitcoin miners are feeling ...
# 4  March 1 (Reuters) - Bitcoin has leapt since Ru...

# %%
# Create the Ethereum sentiment scores DataFrame

ethereum_sentiments = []

for article in ethereum_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "Text": text,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["Compound",  "Negative", "Neutral","Positive","Text"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.3182     0.093    0.848     0.059
# 1    0.6705     0.000    0.812     0.188
# 2   -0.4588     0.083    0.917     0.000
# 3    0.8340     0.050    0.713     0.236
# 4   -0.1326     0.044    0.956     0.000
#
#                                                 Text
# 0  In February, shit hit the fan in the usual way...
# 1  Coinbase reported that the share of trading vo...
# 2  Illustration by James Bareham / The Verge\r\n\...
# 3  If it sounds too good to be true, youre not wr...
# 4  It seems that in 2022, you cant escape from th...

# %%
# Describe the Bitcoin Sentiment

btc_df.describe()
# Out:
#          Compound    Negative     Neutral    Positive
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.069736    0.047440    0.882600    0.069960
# std      0.430337    0.060644    0.083611    0.069317
# min     -0.895700    0.000000    0.694000    0.000000
# 25%     -0.250000    0.000000    0.837500    0.000000
# 50%      0.000000    0.000000    0.891500    0.065000
# 75%      0.401900    0.083000    0.940750    0.096500
# max      0.910000    0.265000    1.000000    0.301000

# %%
# Describe the Ethereum Sentiment

eth_df.describe()
# Out:
#          Compound    Negative     Neutral    Positive
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.141145    0.041270    0.882970    0.075730
# std      0.429460    0.060426    0.083793    0.069882
# min     -0.913600    0.000000    0.688000    0.000000
# 25%      0.000000    0.000000    0.835250    0.000000
# 50%      0.153100    0.000000    0.887000    0.069000
# 75%      0.505200    0.066250    0.943000    0.111750
# max      0.862500    0.312000    1.000000    0.290000

# %%
## Questions:
Q: Which coin had the highest mean positive score?

ETH

Q: Which coin had the highest compound score?

BTC

A: Ethereum had the highest compound score with a score of 0.827100

Q. Which coin had the highest positive score?

BTC
# Out:
#   File "C:\Users\12152\AppData\Local\Temp/ipykernel_51060/26945621.py", line 10
#     A: Ethereum had the highest compound score with a score of 0.827100
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Add stopwords to the default list
sw_addon = {
    "Reuters",
    "reuters",
    "Getty Images",
    "Getty",
    "AP",
    "Dec",
    "Nov",
    "char",
    "ha",
    "day",
    "dec",
    "wa",
    "charswhat"
}
print(sw.union(sw_addon))
# Out:
# {'is', 'under', 'these', 'there', 'i', 'such', 'while', 'off', 'any', 'once', 'it', 'ma', 'more', "wouldn't", 'about', 'dec', "hadn't", 'its', 'being', 'with', 'needn', "shan't", 'your', 'ourselves', 'down', 'and', 'reuters', 'should', 'Getty Images', "you'd", 'doing', 'just', 'ain', 've', "hasn't", 'here', "weren't", 'against', "you'll", 'am', "couldn't", 'hadn', 'very', 'he', 'into', 'above', 'because', 'my', 'you', "shouldn't", 'now', 'wouldn', 'had', 'wa', 'has', 'aren', 'myself', 'who', 'theirs', "didn't", 'are', 'll', "aren't", 'both', 'hasn', 'as', 'couldn', 'mightn', 'the', 'yourselves', 'me', 'whom', 'in', 'when', 'further', 'why', "should've", 'own', 're', 'weren', 'does', 'Dec', 'a', 'itself', 'nor', 'haven', 'shouldn', 'at', 'which', 'if', 'an', 'd', "it's", 'won', "wasn't", 'having', 'himself', 'of', "mightn't", 'few', 'too', 'after', 'their', 'his', 'charswhat', 'yours', 'hers', "needn't", "she's", 'we', 's', 'our', "mustn't", 'o', 'will', 'up', 'on', 'where', "haven't", 'or', 'some', 'was', 'what', 'ours', "you've", 'her', 'other', 'that', 'no', 'over', 'each', 'this', 'them', 't', "isn't", "doesn't", 'they', 'day', 'be', 'how', 'same', 'mustn', 'him', "won't", 'until', 'out', 'can', 'through', 'than', 'themselves', 'during', 'most', 'to', 'wasn', 'she', "don't", 'm', 'for', 'not', 'doesn', 'shan', 'don', 'between', 'Nov', 'then', 'didn', 'but', "that'll", 'did', 'Getty', 'were', 'below', 'only', 'do', 'AP', 'from', 'all', 'char', "you're", 'have', 'again', 'isn', 'so', 'y', 'been', 'herself', 'those', 'yourself', 'before', 'ha', 'Reuters', 'by'}

# %%
# Create the tokenizer function, and combine the tokens into a string (i.e., no list seprated by quotes) at the end
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)   

    # Create a tokenized list of the words
    words = word_tokenize(re_clean)    
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    lower = [word.lower() for word in lem]
    
    # Remove the stop words
    tokens = [word for word in lower if word not in sw.union(sw_addon)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin

btc_df['tokens'] = btc_df['Text'].apply(tokenizer)
btc_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.7351     0.000    0.853     0.147
# 1    0.0000     0.000    1.000     0.000
# 2   -0.7713     0.169    0.831     0.000
# 3   -0.1779     0.067    0.887     0.046
# 4    0.0000     0.000    1.000     0.000
#
#                                                 Text  \
# 0  Even in cyberspace, the Department of Justice ...
# 1  When Russia invaded Ukraine, Niki Proshin was ...
# 2  "Bitcoin was seen by many of its libertarian-l...
# 3  Feb 22 (Reuters) - Bitcoin miners are feeling ...
# 4  March 1 (Reuters) - Bitcoin has leapt since Ru...
#
#                                               tokens
# 0  [even, cyberspace, department, justice, able, ...
# 1  [russia, invaded, ukraine, niki, proshin, alre...
# 2  [bitcoin, seen, many, libertarianleaning, fan,...
# 3  [feb, bitcoin, miner, feeling, heat, pain, rip...
# 4  [march, bitcoin, leapt, since, russias, invasi...

# %%
# Create a new tokens column for Ethereum

eth_df['tokens'] = eth_df['Text'].apply(tokenizer)
eth_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.3182     0.093    0.848     0.059
# 1    0.6705     0.000    0.812     0.188
# 2   -0.4588     0.083    0.917     0.000
# 3    0.8340     0.050    0.713     0.236
# 4   -0.1326     0.044    0.956     0.000
#
#                                                 Text  \
# 0  In February, shit hit the fan in the usual way...
# 1  Coinbase reported that the share of trading vo...
# 2  Illustration by James Bareham / The Verge\r\n\...
# 3  If it sounds too good to be true, youre not wr...
# 4  It seems that in 2022, you cant escape from th...
#
#                                               tokens
# 0  [february, shit, hit, fan, usual, way, old, tw...
# 1  [coinbase, reported, share, trading, volume, e...
# 2  [illustration, james, bareham, verge, million,...
# 3  [sound, good, true, youre, wrong, yield, farmi...
# 4  [seems, cant, escape, metaversefrom, facebook,...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2

btc_string = ' '.join(btc_df.Text)
btc_processed = tokenizer(btc_string)
btc_bigrams = ngrams(btc_processed, n=2)
btc_top_10 = dict(Counter(btc_bigrams).most_common(10))
pd.DataFrame(list(btc_top_10.items()), columns=['bigram', 'count'])
# Out:
#                 bigram  count
# 0          (new, york)      5
# 1  (invasion, ukraine)      4
# 2      (since, russia)      4
# 3        (london, feb)      4
# 4    (russia, invaded)      3
# 5   (invaded, ukraine)      3
# 6     (march, bitcoin)      3
# 7  (russias, invasion)      3
# 8         (joe, biden)      3
# 9  (central, american)      3

# %%
# Generate the Ethereum N-grams where N=2

eth_string = ' '.join(eth_df.Text)
eth_processed = tokenizer(eth_string)
eth_bigrams = ngrams(eth_processed, n=2)
eth_top_10 = dict(Counter(eth_bigrams).most_common(10))
pd.DataFrame(list(eth_top_10.items()), columns=['bigram', 'count'])
# Out:
#                    bigram  count
# 0      (venture, capital)      5
# 1          (hit, billion)      4
# 2    (nonfungible, token)      4
# 3  (cryptocurrency, boom)      3
# 4            (boom, past)      3
# 5            (past, year)      3
# 6          (year, helped)      3
# 7        (helped, propel)      3
# 8         (propel, newer)      3
# 9         (newer, market)      3

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin

pd.DataFrame(token_count(eth_processed), columns=['word', 'count'])
# Out:
#                word  count
# 0    cryptocurrency     16
# 1  cryptocurrencies     16
# 2          ethereum     15

# %%
# Use token_count to get the top 10 words for Ethereum

pd.DataFrame(token_count(btc_processed), columns=['word', 'count'])
# Out:
#              word  count
# 0         bitcoin     35
# 1  cryptocurrency     19
# 2         ukraine     18

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud

wc = WordCloud().generate(btc_string)
plt.title('Bitcoin Word Cloud', fontsize=25, fontweight='bold')
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud

wc = WordCloud().generate(eth_string)
plt.title('Ethereum Word Cloud', fontsize=25, fontweight='bold')
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy
# Out:
# C:\Users\12152\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\12152\anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\12152\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together

bitcoin_text = btc_df['Text'].str.cat()
bitcoin_text
# Out:
# 'Even in cyberspace, the Department of Justice is able to use a tried and true investigative technique, following the money, Ms. Monaco said. Its what led us to Al Capone in the 30s. It helped us dest… [+1176 chars]When Russia invaded Ukraine, Niki Proshin was already a year into making a living as a vlogger — he had a YouTube channel, a TikTok channel, and an Instagram. He also ran an online Russian club for a… [+5883 chars]"Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance," argues a columnist in the New York Times, "a form of \'digital gold\' that would be a source of stability as … [+3914 chars]Feb 22 (Reuters) - Bitcoin miners are feeling the heat - and the pain\'s rippling downstream to pressure prices.\r\nThe cryptocurrency\'s spectacular rally in 2021 drew thousands of entrants into mining,… [+4196 chars]March 1 (Reuters) - Bitcoin has leapt since Russia\'s invasion of Ukraine, bolstered by people in those countries looking to store and move money in anonymous and decentralised crypto.\r\nBitcoin tradin… [+3955 chars]Whose side is cryptocurrency on? If you had asked Satoshi Nakamoto, the pseudonymous person (or persons) who created the Bitcoin platform in 2008, he/they likely would have rejected the question. The… [+3643 chars]Getty\r\nWelcome to Nonfungible Tidbits. Our focus this week: Russia\'s war in Ukraine.\xa0\r\nIn addition to uprooting the lives of Ukrainians and throwing the international order into chaos, the Russian in… [+3275 chars]An appeals court decided shilling for an unregistered security on YouTube is the same thing as doing it in a letter.\r\nIllustration by Alex Castro / The Verge\r\nThe story of BitConnect doesnt include a… [+3046 chars]Nurphoto/Getty\r\nAs Russia launched an invasion into his home country last Thursday, Ukranian photographer Vitaliy Raskalov found himself a world away in Mexico City. When I spoke with him over Telegr… [+7815 chars]LONDON, March 4 (Reuters) - Cryptocurrencies have been close to the headlines since Russia invaded Ukraine, with the ever-volatile bitcoin in demand in Russia and beyond.\r\nHere are some charts that l… [+3634 chars]March 15 (Reuters) - Bitcoin loves flirting with the mainstream. But now, as the U.S. president says he wants to get serious, it may be getting cold crypto feet.\r\nWhen Joe Biden ordered officials to … [+4501 chars]Feb 24 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nBITCOIN, NOT EXACTLY A … [+6882 chars]<ul><li>\r\nSummary</li><li>\r\nLaw firms</li><li>\r\nRelated documents</li></ul>\r\nThe company and law firm names shown above are generated automatically based on the text of the article. We are improving … [+2414 chars]The Ukrainian government asking for donations in bitcoin shows the utility of the cryptocurrency and is a positive sign for the market, veteran strategist Tom Lee has said.\r\nUkraine government accoun… [+1750 chars]Don\'t expect bitcoin to double or triple in price anytime soon, going by "Shark Tank" investor Kevin O\'Leary\'s prediction.\r\n"If you want to talk about bitcoin going to $100,000, $200,000, $300,000, i… [+2200 chars]Bitcoin rallied to a two-week high on Tuesday in spite of the turmoil on the broader markets, thanks to a surge in buying by Russians and Ukrainians who may be seeking refuge in cryptocurrencies as t… [+2894 chars]SAN SALVADOR, March 11 (Reuters) - El Salvador is looking for the right timing to launch its bitcoin-backed bond, which could happen between March 15 and 20, the Central American nation\'s finance min… [+533 chars]SAN SALVADOR, Feb 20 (Reuters) - El Salvador President Nayib Bukele on Sunday said he will send Congress a proposal to grant citizenship to foreigners who invest in the Central American country as we… [+1144 chars]Motherboard found old footage from one of the first major Bitcoin conferences: Bitcoin 2013 in San Jose ...

# %%
# Run the NER processor on all of the text

btc_doc = nlp(bitcoin_text)

# Add a title to the document

btc_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization

displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Even in cyberspace,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Department of Justice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is able to use a tried and true investigative technique, following the money, Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monaco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. Its what led us to
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Al Capone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  in the 30s. It helped us dest… [+1176 chars]When
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  invaded
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niki Proshin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was already
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into making a living as a vlogger — he had a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  channel, a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TikTok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  channel, and an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . He also ran an online
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  club for a… [+5883 chars]&quot;Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance,&quot; argues a columnist in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , &quot;a form of 'digital gold' that would be a source of stability as … [+3914 chars]Feb
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The cryptocurrency's spectacular rally in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  drew
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of entrants into mining,… [+4196 chars]March 1 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin has leapt since
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's invasion of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Bitcoin tradin… [+3955 chars]Whose side is cryptocurrency on? If you had asked
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakamoto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the pseudonymous person (or persons) who created the Bitcoin platform in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>Welcome to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nonfungible Tidbits
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Our focus
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </

# %%
# List all Entities

[ent.text for ent in btc_doc.ents]
# Out:
# ['the Department of Justice',
#  'Monaco',
#  'Al Capone',
#  'Russia',
#  'Ukraine',
#  'Niki Proshin',
#  'a year',
#  'YouTube',
#  'TikTok',
#  'Instagram',
#  'Russian',
#  'the New York Times',
#  '22',
#  'Reuters',
#  '2021',
#  'thousands',
#  'Reuters',
#  'Russia',
#  'Ukraine',
#  'Satoshi Nakamoto',
#  '2008',
#  'Nonfungible Tidbits',
#  'this week',
#  'Russia',
#  'Ukraine',
#  'Ukrainians',
#  'Russian',
#  'YouTube',
#  'Alex Castro',
#  'Verge',
#  'BitConnect',
#  'Getty',
#  'Russia',
#  'last Thursday',
#  'Ukranian',
#  'Mexico City',
#  'Telegr',
#  'March 4',
#  'Reuters',
#  'Russia',
#  'Ukraine',
#  'Russia',
#  '15',
#  'Reuters',
#  'U.S.',
#  'Joe Biden',
#  'Reuters',
#  'BITCOIN',
#  '+6882 chars]<ul><li>',
#  'Summary</li><li>',
#  'Law firms</li><li>\r\n',
#  'documents</li></ul',
#  'Ukrainian',
#  'Tom Lee',
#  'Ukraine',
#  'Shark Tank',
#  "Kevin O'Leary's",
#  '100,000',
#  '200,000',
#  '300,000',
#  'two-week',
#  'Tuesday',
#  'Russians',
#  'Ukrainians',
#  'March 11',
#  'Reuters',
#  'El Salvador',
#  'between March 15 and 20',
#  'Central American',
#  'Feb 20',
#  'Reuters',
#  'El Salvador',
#  'Nayib Bukele',
#  'Sunday',
#  'Congress',
#  'Central American',
#  'one',
#  'first',
#  'Bitcoin',
#  'Bitcoin 2013',
#  'San Jose',
#  '2013',
#  'only 9 years',
#  'Satish Kumbhani',
#  'BitConnect',
#  'last week',
#  '$2.4 billion',
#  'Ponzi',
#  'James Bareham',
#  'More than $15 million',
#  'More than $15 million',
#  'Ukrainian',
#  'Russia',
#  'Ting Shen',
#  'Bloomberg',
#  'Montana',
#  'years',
#  'one',
#  '24',
#  'Reuters',
#  'Thursday',
#  'Feb 25',
#  'Reuters',
#  'Ukrainian',
#  '$4 million',
#  'Russia',
#  'Thursday',
#  'Feb 27',
#  'Reuters',
#  'Ukraine',
#  'almost $8 million',
#  'March 9',
#  'Reuters',
#  'Wednesday',
#  'U.S. Treasury',
#  'Ukrainian',
#  'more than $4 million',
#  'Russia',
#  'Elliptic',
#  'late 2024',
#  'one',
#  'Hu',
#  'last year',
#  'Between 2020 and 2021',
#  'Russians',
#  'Mark Mobius',
#  'Russia',
#  'Ukraine',
#  'Thursday',
#  'US',
#  'above $40,000',
#  'Wednesday',
#  'US',
#  'Treasury',
#  'Janet Yellen',
#  'Biden',
#  'Mike Novogratz',
#  'Digital',
#  'Federal Reserve',
#  'Vladimir Putin',
#  'Heinemeier Hansson',
#  'Twitter',
#  'Monday',
#  'chars]Russia',
#  'Ukraine',
#  "El Salvador's",
#  '$1 billion',
#  'El Salvador',
#  'Central American',
#  'last year',
#  'Ukraine',
#  'CNET',
#  'Artyom Fedosov',
#  'early this week',
#  'Ukraine',
#  'Russian',
#  '40,000',
#  'the weekend',
#  'this weeks',
#  'Marina Hyde',
#  'London',
#  'Zoe Williams',
#  'Charlie Brooker',
#  'Annie',
#  '19m11s',
#  'Luke Winkie',
#  'Michael Saylor',
#  'the PBD Podcast',
#  'Reuters',
#  'Elon Musk',
#  'World War 3',
#  'Russia',
#  'Ukraine',
#  'chars]NEW YORK',
#  'Feb 24',
#  'Reuters',
#  'U.S.',
#  'Thursday',
#  'Feb 23',
#  'Reuters Breakingviews',
#  'this year',
#  'chars]In',
#  'first',
#  'gre',
#  'Feb 28',
#  'Reuters',
#  'Russian',
#  'Tether',
#  'Monday',
#  'Tuesday',
#  'Holden',
#  'Joe Biden',
#  'months',
#  'Biden',
#  'chars]NEW YORK',
#  'March 4',
#  'Reuters',
#  'U.S.',
#  'the latest week',
#  'mid-August 2021',
#  'Reuters',
#  'U.S.',
#  'Russia',
#  'Ukraine',
#  'Bloomberg',
#  'Getty Images',
#  '$3 trillion',
#  'less than $2 trillion',
#  'today',
#  'West',
#  'Russia',
#  'Vladimir Putin',
#  'Ukraine',
#  'the United States',
#  'Ukraine',
#  'Ukraine',
#  'millions',
#  'West',
#  '+8651 chars](CNN Business)As',
#  'Biden',
#  'Wednesday',
#  'first',
#  'Ormeus Coin',
#  'BitConnect',
#  '$2.4 billion',
#  'Ponzi',
#  'San Diego',
#  'Conti',
#  'one',
#  'pro-Russian',
#  'Musk',
#  'Monday',
#  'Musk',
#  'Tesla',
#  'Musk',
#  'Monday',
#  'Musk',
#  'Tesla',
#  'San Diego',
#  'BitConnect',
#  'BCC',
#  'Seymour',
#  'Seymour Asset Management',
#  'Meltem Demirors',
#  'CoinShares',
#  'Melissa Francis',
#  'chars]New York',
#  'Miami',
#  'US',
#  'Bloomberg News',
#  'New Yorkers',
#  'Motherboard',
#  'Motherboard',
#  'Summary</li><li>',
#  'Law firms</li><li>\r\n',
#  'documents</li></ul',
#  'Kyiv',
#  'Mykhailo Fedoro',
#  'Wednesday',
#  'Russia',
#  'Ukraine',
#  'two hours',
#  'YouTube',
#  'Waka Flacka Fla',
#  '2,000',
#  'Monday',
#  'August 2020',
#  'Palladium',
#  'Europe',
#  'UK',
#  'today',
#  'CoinDesk',
#  'the last few years',
#  'Russia',
#  'Ukraine',
#  '1,940',
#  'Wednesday',
#  'June 202',
#  'Blockchain',
#  'Blockchain',
#  '19',
#  'Feb 2022',
#  'Date Written',
#  'February 16, 2022\r\n',
#  'Abstract',
#  'December 2020',
#  'Visa',
#  'Mastercard',
#  'Discover',
#  'Pornhub',
#  'Canada',
#  'Kuna.io',
#  'March 10',
#  'Reuters',
#  'Canadian',
#  'the United States',
#  'NetWalker',
#  'March 8',
#  'Reuters',
#  'Thailand',
#  'Tuesday',
#  'chars]NEW YORK',
#  'March 14',
#  'Reuters',
#  'Russi',
#  'Bitcoin, Ethereum',
#  'DogeCoin',
#  'Binance',
#  'June 28, 2021',
#  'REUTERS',
#  'Dado Ruvic/Illus',
#  'Friday',
#  'February',
#  'Ukraine',
#  'Dow',
#  'more than rubles',
#  'Ukraine',
#  'Mykhailo Fedorov',
#  'today',
#  'Ukraine',
#  'Russ',
#  'Feb. 17.Scott',
#  'Olson/Getty Images North America',
#  'Ontario Superior Court',
#  'Calum MacLeod',
#  'third',
#  'March 9',
#  'Monday',
#  'morning',
#  'Garlick',
#  'Getty',
#  'Canada',
#  'one',
#  'US',
#  'Canadian',
#  'UK',
#  'ATMs',
#  'Getty\r\nRegulators',
#  'UK',
#  'ATMs',
#  'The Financial Conduct Authority',
#  'Carlo Cadenas',
#  'Verge',
#  'Russia',
#  'Ukraine',
#  'its fifth day',
#  'US',
#  'Europe',
#  '100,000',
#  'Ukraine',
#  'Russian',
#  'Thursday',
#  'Russia',
#  'Ukraine',
#  'Northrop Grumman',
#  'about 3%',
#  'Lockheed Martin',
#  'Raytheon Technologi',
#  'Wednesday',
#  'Western',
#  'Russia',
#  'two',
#  'Uk',
#  '15',
#  'Reuters',
#  'ConsenSys',
#  'Tuesday',
#  'over $7 billion',
#  'SoftBank',
#  'March 3',
#  'Reuters',
#  'Ukraine',
#  'Thursday',
#  'Kyiv',
#  'Monday',
#  'Russia',
#  'Ukraine',
#  'two',
#  '500',
#  'Dow',
#  'today',
#  'the Ukrainian Red Cross',
#  'Red Cross',
#  'March 11',
#  'Reuters',
#  'the United Arab Emirates',
#  'billions of dollars',
#  'Russians',
#  'Jared Polis',
#  'Colorado',
#  'first',
#  'Facebook']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together

ethereum_text = eth_df['Text'].str.cat()
ethereum_text
# Out:
# 'In February, shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at Ethereum Name Service (ENS), a web3 business, had written the following in May 201… [+3096 chars]Coinbase reported that the share of trading volume for ethereum and other altcoins increased last year, while bitcoin\'s share dropped dramatically.\xa0\r\nBetween 2020 and 2021, ethereum trading volume in… [+1187 chars]Illustration by James Bareham / The Verge\r\n\n \n\n\n More than $15 million has been donated so far More than $15 million in cryptocurrency has been donated to Ukrainian groups since Russia attacked the c… [+7442 chars]If it sounds too good to be true, youre not wrong. Yield farming is riskier than staking. The tokens that are offering such high interest rates and fee yields are also the ones most likely to take a … [+2371 chars]It seems that in 2022, you cant escape from the metaverse.\xa0From Facebook to Microsoft, seemingly every centralized tech firm is clambering on the bandwagon of this emerging virtual reality. For puris… [+5412 chars]At over two hours long, the wildly popular new YouTube documentary\xa0 "Line Goes Up The Problem With NFTs" is an exhaustive takedown of the hot new investment vehicle that everyone from Waka Flacka Fla… [+2929 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nIn fact, total NFT sales volume hit $23 billion over the past… [+2680 chars]A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet. You can find past issues of the newsletter here.\r\nLast wee… [+7988 chars]Joe Biden is dipping his toes into crypto. On Wednesday, the president signed a first-of-its-kind executive order outlining a path to regulation of cryptocurrencies and encouraging federal agencies t… [+2590 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nIn fact, total NFT sales volume hit $23 billion over the past… [+2603 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nIn fact, total NFT sales volume hit $23 billion over the past… [+2633 chars]If blockchain technology is to reach true mass adoption, it will have to become cheaper and more efficient. Low transaction throughput on some of the most popular blockchains, most notably Ethereum, … [+1852 chars]The news:\xa0Blockchain specialist\xa0ConsenSys\xa0scooped $450 million\xa0in a Series D round that values the US-based firm at over $7 billion, per a press release. Its valuation has more than doubled since its… [+2949 chars](Kitco News) The escalating Russia-Ukraine crisis, new sanctions, and surging oil prices have investors fleeing risk-on assets. And the crypto space is getting its safe-haven appeal back as more peop… [+3790 chars]During the days leading up to the March 11 purchase by Yuga Labs of the intellectual property of the Meebits collection from Larva Labs, more than a dozen addresses on the Ethereum blockchain purchas… [+556 chars]Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+5248 chars]The travel services industry and fast-food chains are among those leading the widening acceptance of cryptocurrencies as payment for goods and services, research released Tuesday showed.\xa0\r\nOf the top… [+2321 chars]A Ukrainian nonprofit has raised bitcoin worth more than $4 million to support the country\'s army since Russia attacked, according to blockchain analytics company Elliptic.\r\nCome Back Alive a charita… [+2415 chars]As the international community rallies around Ukraine amid Russia\'s\xa0invasion, cryptocurre ...

# %%
# Run the NER processor on all of the text

eth_doc = nlp(ethereum_text)
# Add a title to the document

eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization

displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Name Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ENS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), a web3 business, had written the following in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 201
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# … [+3096 chars]Coinbase reported that the share of trading volume for ethereum and other altcoins increased
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Between 2020 and 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , ethereum trading volume in… [+1187 chars]Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Bareham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br> </br></br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  has been donated so far
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in cryptocurrency has been donated to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukrainian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  groups since
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  attacked the c… [+7442 chars]If it sounds too good to be true, youre not wrong. Yield farming is riskier than staking. The tokens that are offering such high interest rates and fee yields are also the ones most likely to take a … [+2371 chars]It seems that in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , you cant escape from the metaverse. From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , seemingly every centralized tech firm is clambering on the bandwagon of this emerging virtual reality. For puris… [+5412 chars]At over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  long, the wildly popular new
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  documentary  &quot;Line Goes Up The Problem With NFTs&quot; is an exhaustive takedown of the hot new investment vehicle that everyone from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Waka Flacka Fla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+2929 chars]The cryptocurrency boom over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past few years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>In fact, total
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sales volume hit
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $23 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  over the past… [+2680 chars]A version of this article was published in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TIME
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s newsletter Into the Metaverse. Subscribe for a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bol

# %%
# List all Entities

[ent.text for ent in eth_doc.ents]
# Out:
# ['February',
#  'Ethereum Name Service',
#  'ENS',
#  'May 201',
#  'last year',
#  'Between 2020 and 2021',
#  'James Bareham',
#  'More than $15 million',
#  'More than $15 million',
#  'Ukrainian',
#  'Russia',
#  '2022',
#  'Facebook',
#  'Microsoft',
#  'two hours',
#  'YouTube',
#  'Waka Flacka Fla',
#  'the past few years',
#  'NFT',
#  '$23 billion',
#  'TIME',
#  'weekly',
#  'Biden',
#  'Wednesday',
#  'first',
#  'the past few years',
#  'NFT',
#  '$23 billion',
#  'the past few years',
#  'NFT',
#  '$23 billion',
#  'Ethereum',
#  '$450 million',
#  'Series',
#  'US',
#  'over $7 billion',
#  'Russia',
#  'Ukraine',
#  'days',
#  'March 11',
#  'Yuga Labs',
#  'Meebits',
#  'Larva Labs',
#  'more than a dozen',
#  'Ethereum',
#  'American Express',
#  'Tuesday',
#  'Ukrainian',
#  'more than $4 million',
#  'Russia',
#  'Elliptic',
#  'Ukraine',
#  'Russia',
#  'Elliptic',
#  'nearly $55 million',
#  'Russia',
#  'Ukraine',
#  'Bloomberg',
#  'Getty Images',
#  'Bitcoin, Ethereum',
#  'DogeCoin',
#  'Binance',
#  'June 28, 2021',
#  'REUTERS',
#  'Dado Ruvic/Illus',
#  'only one',
#  'NFT',
#  'Russia',
#  'Ukraine',
#  'Niki Proshin',
#  'a year',
#  'YouTube',
#  'TikTok',
#  'Instagram',
#  'Russian',
#  'Wednesday, March 23',
#  'TIME',
#  'first',
#  'NFT',
#  'NFT',
#  'TIME',
#  'The Prince of Crypto Has',
#  'Kyiv',
#  'Mykhailo Fedoro',
#  'chars]MetaMask',
#  'Infura',
#  'two',
#  'Ethereum',
#  'MetaMask',
#  'BTCUSD',
#  '+5.43%',
#  'ETHUSD',
#  '+4.96%',
#  'recent years',
#  '15',
#  'Reuters',
#  'ConsenSys',
#  'Tuesday',
#  'over $7 billion',
#  'SoftBank',
#  'American Express',
#  "Kevin O'Leary",
#  'Friday',
#  '20%',
#  'CNBC',
#  'Finance Insider',
#  'American Express',
#  'Ape Yacht',
#  'Yugo Labs',
#  'CryptoPunks',
#  'Larva Labs',
#  'over three',
#  'Europe',
#  'Russian',
#  'Ukraine',
#  'Vladimir Putin',
#  'February 24',
#  'Ukraine',
#  'Ukraine',
#  'millions',
#  'West',
#  'at least one',
#  'One',
#  "Sean O'Brien",
#  'Ukrainian',
#  'Tom Lee',
#  'Ukraine',
#  '2,000',
#  'Monday',
#  'August 2020',
#  'Palladium',
#  'Alex Castro',
#  'the App Store One',
#  'Jack Dorsey',
#  'Reuters',
#  'Australian',
#  'NFT',
#  'Singapore',
#  'Temasek',
#  '$2.5 billion',
#  'Monday',
#  'the Data Summit',
#  'Joel Dietz',
#  'MetaMask',
#  'chars]One year ago',
#  'US$69 million',
#  '£52.6 million',
#  'Christies',
#  'Matisse',
#  'Van Gogh',
#  'Litecoin',
#  'one',
#  'DApps',
#  'NFT',
#  'Shark Tank',
#  "Kevin O'Leary's",
#  '100,000',
#  '200,000',
#  '300,000',
#  'Massachusetts Institute of Technology',
#  'MIT',
#  '2022',
#  'Ethereum',
#  'MIT',
#  '+3186',
#  'more than rubles',
#  'Ukraine',
#  'Mykhailo Fedorov',
#  'today',
#  'Ukraine',
#  'Russ',
#  'late 2024',
#  'one',
#  'Hu',
#  'Russians',
#  'Mark Mobius',
#  'Russia',
#  'Ukraine',
#  'Thursday',
#  'US',
#  'Musk',
#  'Monday',
#  'Musk',
#  'Tesla',
#  'Musk',
#  'Monday',
#  'Musk',
#  'Tesla',
#  'November',
#  'Universal Music',
#  'Bloomberg',
#  'three',
#  'Kingship',
#  'Samsung Digital Wallet',
#  'Samsung Digital WalIet',
#  'just two',
#  'Become a Premium Member',
#  '3',
#  '+395',
#  'GeForce',
#  'GPU',
#  'Wednesday',
#  'Western',
#  'Russia',
#  'two',
#  'Uk',
#  'two-week',
#  'Tuesday',
#  'Russians',
#  'Ukrainians',
#  'The United States',
#  'about US$1.1 trillion',
#  '£830 billion',
#  '2003',
#  'Iraq war',
#  'UK',
#  'about £2.6 billion',
#  'Russian',
#  'Ukraine',
#  'the International Space Station',
#  'Business)As',
#  'Elixir',
#  'weekly',
#  'Joe Biden',
#  'months',
#  'Biden',
#  'Cuban',
#  'Musk',
#  'the coming years',
#  '+2739',
#  'Elixir',
#  'weekly',
#  'US',
#  'European',
#  'Thursday',
#  'Russia',
#  'Ukraine',
#  'Turkey',
#  '+3231',
#  'above $40,000',
#  'Wednesday',
#  'US',
#  'Treasury',
#  'Janet Yellen',
#  'Biden',
#  '20 years ago',
#  'Cut Off From Global Economy',
#  'Russia',
#  'Ukraine',
#  'Insights Newsletter',
#  '724,948',
#  'tomorrow',
#  'Two weeks ago',
#  'Miami',
#  'two',
#  '500',
#  'B.C.',
#  '2021',
#  'Nonfungible.com',
#  'NFT',
#  '$5.17 billion',
#  'the year',
#  'LAtelier BNP Paribas',
#  'NonFungible.com',
#  'today',
#  'the Data Summit',
#  'March 9th',
#  'Sadie Williamson',
#  'Williamson Fintech Consulting',
#  'Nvidia’s',
#  'LHR',
#  'Custo',
#  'Viltrakyte',
#  'Soviet',
#  'winter',
#  'Bali',
#  'Lithuanian',
#  'last week',
#  '2.75%',
#  'ETH',
#  'two years',
#  '2017-2019',
#  'Thursday',
#  'Federal Reserve',
#  'Jerome Powell',
#  'a rough weekend',
#  'the trading week',
#  'Tuesday',
#  'Russia',
#  'the next decade',
#  'recent days',
#  '13%',
#  '$1.9 trillion',
#  '2022',
#  'Russias',
#  'Ukraine',
#  'Anonymous',
#  'Thursday',
#  'Thursday',
#  'Russian',
#  'Ukraine',
#  "last year's",
#  'Shiba Inu',
#  'SHIB',
#  '33%',
#  '45,000,000',
#  '0.86%',
#  'ETH',
#  '1.11%',
#  'Ethereum',
#  'first',
#  'Nori',
#  'Three',
#  '10',
#  'Solana\xa0',
#  '2.60%',
#  'Cardano\xa0',
#  'ADA',
#  '3.24%',
#  'Avalanche',
#  '4.46%',
#  'ETH',
#  '-1.20%',
#  'Ethereum',
#  'Ethereum',
#  'about $100,000',
#  '10 minutes',
#  'recent years',
#  'Ukraine',
#  'Ukraine',
#  'Russia',
#  'Waves( WAVES 5.62%',
#  '50%',
#  '2022',
#  'over 200',
#  'Gate.io',
#  'NFT',
#  'more than 1,000']

# %% [markdown]
# ---
